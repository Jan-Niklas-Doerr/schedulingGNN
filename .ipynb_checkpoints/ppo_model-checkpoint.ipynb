# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torch.nn.functional as F
from simulations import sim_randomised, sim_constrained, sim_automated
import random
import matplotlib.pyplot as plt
from torch.distributions import Categorical

#GNN related imports
import torch_geometric.nn as geom_nn

from torch_geometric.nn import MessagePassing
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp
from torch_geometric.data import Data
from torch_geometric.data import Batch

import torch.optim as optim


import math

# %%
# %load_ext autoreload
# %autoreload 2

# %%
class ActorCritic(nn.Module):
    def __init__(self, n_states, n_actions, hidden_dim=32):
        super(ActorCritic, self).__init__()
        
        self.n_actions = n_actions
        
        self.actor = nn.Sequential(
            nn.Linear(gnn_output_dim, hidden_dim),
            nn.PReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(),
            nn.Linear(hidden_dim, n_actions),
        )
        self.critic = nn.Sequential(
            nn.Linear(gnn_output_dim, hidden_dim),
            nn.PReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(),
            nn.Linear(hidden_dim, 1),
        )

    def forward(self, graph_feature_vector,action_mask,temperature=1.0):
        logits = self.actor(graph_feature_vector) / temperature
        #print(logits, "direct logits")
        logits += action_mask
        #print(logits)
        
        action_probs = F.softmax(logits, dim=-1)
        state_value = self.critic(graph_feature_vector)
        return action_probs, state_value

# %%
class PPO:
    def __init__(self, 
                 n_states, 
                 n_actions,
                 lr_actor,
                 lr_critic,
                 gamma,
                 K_epochs,
                 eps_clip,
                 gae_lambda):
        
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        self.gae_lambda = gae_lambda

        self.policy = ActorCritic(gnn_output_dim, n_actions)
        self.optimizer = optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': lr_actor},
            {'params': self.policy.critic.parameters(), 'lr': lr_critic}
        ])
        
        self.scheduler = torch.optim.lr_scheduler.ExponentialLR(self.optimizer, gamma=0.9998)

        self.policy_old = ActorCritic(gnn_output_dim, n_actions)
        self.policy_old.load_state_dict(self.policy.state_dict())

        self.MseLoss = nn.MSELoss()

    def select_action(self, state_data, memory,action_mask, temperature=1.0):
        
        # Not sure if I need it
        #state = torch.FloatTensor(state.reshape(1, -1))
        
        gnn_output = self.gnn_processor(state_data)
        
        with torch.no_grad():
            masked_action_probs, _ = self.policy_old(gnn_output, action_mask, temperature)
        
        dist = Categorical(masked_action_probs)
        action = dist.sample()
        
        
        memory.states.append(state_data)
        memory.actions.append(action)
        memory.masks.append(torch.tensor(action_mask))
        memory.logprobs.append(dist.log_prob(action))

        return action

    def update(self, memory):
        gae, targets = self.calculate_gae_and_targets(memory)


        old_states = Batch.from_data_list(memory.states)
        old_actions = torch.squeeze(torch.stack(memory.actions)).detach()
        old_masks = torch.squeeze(torch.stack(memory.masks)).detach()
        old_logprobs = torch.squeeze(torch.stack(memory.logprobs)).detach()
        losses = []
        
        # Normalizing the rewards
        gae = torch.tensor(gae)
        gae = (gae - gae.mean()) / (gae.std() + 1e-7)

        for _ in range(self.K_epochs):
            # Evaluate old actions and values
            gnn_outputs = self.gnn_processor(old_states)
            logprobs, state_values = self.policy(gnn_outputs,old_masks)
            state_values = torch.squeeze(state_values)
            dist_entropy = -torch.sum(logprobs * torch.exp(logprobs), dim=1)
            new_logprobs = logprobs.gather(1, old_actions.view(-1, 1)).squeeze()
            
            # Find the ratio (pi_theta / pi_theta__old)
            ratios = torch.exp(new_logprobs - old_logprobs)
            
            # Calculate surrogate losses
            surr1 = ratios * gae
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * gae
            
            # Final loss
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, targets) - 0.01*dist_entropy
            
            # Take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
            losses.append(loss.mean().detach().cpu().numpy())
        
        # Copy new weights into old policy
        self.policy_old.load_state_dict(self.policy.state_dict())
        return losses
        
    def calculate_gae_and_targets(self, memory):
        gae = 0
        targets = []
        gae_values = []
        values = memory.values + [0]
    
        for i in reversed(range(len(memory.rewards))):
            delta = memory.rewards[i] + self.gamma * values[i+1] * (1 - memory.is_terminals[i]) - values[i]
            gae = delta + self.gamma * self.gae_lambda * gae * (1 - memory.is_terminals[i])
            gae_values.insert(0, gae)
            targets.insert(0, gae + values[i])

        gae_values = torch.tensor(gae_values, dtype=torch.float32)
        targets = torch.tensor(targets, dtype=torch.float32)

        return gae_values, targets

# %%
class Memory:
    def __init__(self):
        self.actions = []
        self.masks = []
        self.states = []
        self.rewards = []
        self.is_terminals = []
        self.logprobs = []
        self.values = []


    def clear_memory(self):
        del self.actions[:]
        del self.masks[:]
        del self.states[:]
        del self.rewards[:]
        del self.is_terminals[:]
        del self.logprobs[:]
        del self.values[:]

# %%
def show(losses, success_rates):
    figure, axis = plt.subplots(2, 1,figsize=(20, 15) )

    x = range(len(losses))
    a, b = np.polyfit(x,losses , 1)

    axis[0].plot(x, losses)

    x = range(len(success_rates))
    # Creating the plot

    a, b = np.polyfit(x,success_rates , 1)

    axis[1].scatter(x, success_rates)

    axis[1].plot(x, a*x+b,color='red',linewidth=4.5)

    plt.show()

# %%
# Initialize your environment and the PPO agent
env = sim_constrained.Env(visualise=False, verbose=False, model=True,goal="min_time", graph = True)
node_feature_dim = env.node_feature_dim
gnn_output_dim = 128 # Proposed gnn output 

print(node_feature_dim)

n_states = env.n_states
n_actions = env.n_actions

ppo_agent = PPO(node_feature_dim, gnn_output_dim, n_actions, lr_actor=4e-4, lr_critic=2e-3, lr_graph=2e-4, gamma=0.97, K_epochs=6, eps_clip=0.08, gae_lambda=0.97)
memory = Memory()

initial_temperature = 2  # Starting temperature
final_temperature = 1    # Minimum temperature
decay_rate = 0.002          # Rate of temperature decay
current_temperature = initial_temperature

# Training loop
num_episodes = 2000
success_rates = []
losses = []

for episode in range(num_episodes):
    if not (episode + 1) % 25:
        print("episode ", episode+1, " is done!")
        show(losses, success_rates)
        print(current_temperature)
        # Optional: print the current learning rate
        current_lr = ppo_agent.scheduler.get_last_lr()  # get_last_lr returns a list for each param group
        print(f"Epoch {episode+1}: Current Learning Rate: {current_lr}")
    
    current_temperature = max(final_temperature, initial_temperature * (1 - decay_rate * episode))


    _, state_data, action_mask = env.reset()


    #print(current_temperature)
        
    done = False

    while not done:
        action = ppo_agent.select_action(state_data, memory, action_mask)
        #print(action)
        state_data, reward, done, action_mask, success_rate = env.step(action)
        
        #print(state_data, reward, done, success_rate )
        
        if done:
            #reward += math.exp(success_rate / 10 )
            reward -= 2 * math.exp(success_rate/100 )

        # Save in memory
        memory.rewards.append(reward)
        memory.is_terminals.append(done)
        state_temp = ppo_agent.gnn_processor(state_data)
        with torch.no_grad():
            _, state_value = ppo_agent.policy_old(torch.FloatTensor(state_temp).unsqueeze(0), action_mask)
            memory.values.append(state_value)
        
        
        
    
    success_rates.append(success_rate)
    #print(success_rate)
    
    # Update PPO agent
    losses += ppo_agent.update(memory)
    
    ppo_agent.scheduler.step()
    
    memory.clear_memory()

    # Log results, etc.
# Out:
# 26
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  25  is done!
# 1.908
# Epoch 25: Current Learning Rate: [0.0003980844095299955, 0.001990422047649977, 0.00019904220476499776]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  50  is done!
# 1.808
# Epoch 50: Current Learning Rate: [0.0003960987571785572, 0.0019804937858927864, 0.0001980493785892786]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  75  is done!
# 1.708
# Epoch 75: Current Learning Rate: [0.00039412300929754393, 0.0019706150464877197, 0.00019706150464877196]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  100  is done!
# 1.608
# Epoch 100: Current Learning Rate: [0.00039215711648327487, 0.0019607855824163734, 0.00019607855824163743]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  125  is done!
# 1.508
# Epoch 125: Current Learning Rate: [0.00039020102957849624, 0.0019510051478924797, 0.00019510051478924812]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  150  is done!
# 1.408
# Epoch 150: Current Learning Rate: [0.00038825469967115097, 0.0019412734983557537, 0.00019412734983557549]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  175  is done!
# 1.3079999999999998
# Epoch 175: Current Learning Rate: [0.00038631807809315675, 0.0019315903904657814, 0.00019315903904657837]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  200  is done!
# 1.208
# Epoch 200: Current Learning Rate: [0.00038439111641918824, 0.0019219555820959387, 0.00019219555820959412]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  225  is done!
# 1.108
# Epoch 225: Current Learning Rate: [0.0003824737664654666, 0.0019123688323273305, 0.0001912368832327333]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  250  is done!
# 1.008
# Epoch 250: Current Learning Rate: [0.00038056598028855446, 0.0019028299014427702, 0.00019028299014427723]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  275  is done!
# 1
# Epoch 275: Current Learning Rate: [0.00037866771018415737, 0.0018933385509207854, 0.00018933385509207869]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  300  is done!
# 1
# Epoch 300: Current Learning Rate: [0.000376778908685931, 0.001883894543429653, 0.0001883894543429655]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  325  is done!
# 1
# Epoch 325: Current Learning Rate: [0.00037489952856429345, 0.0018744976428214657, 0.00018744976428214673]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  350  is done!
# 1
# Epoch 350: Current Learning Rate: [0.0003730295228252452, 0.0018651476141262242, 0.0001865147614126226]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  375  is done!
# 1
# Epoch 375: Current Learning Rate: [0.00037116884470919366, 0.0018558442235459668, 0.00018558442235459683]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  400  is done!
# 1
# Epoch 400: Current Learning Rate: [0.00036931744768978376, 0.0018465872384489175, 0.00018465872384489188]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  425  is done!
# 1
# Epoch 425: Current Learning Rate: [0.00036747528547273494, 0.0018373764273636737, 0.00018373764273636747]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  450  is done!
# 1
# Epoch 450: Current Learning Rate: [0.0003656423119946833, 0.0018282115599734157, 0.00018282115599734165]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  475  is done!
# 1
# Epoch 475: Current Learning Rate: [0.0003638184814220298, 0.0018190924071101488, 0.0001819092407110149]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  500  is done!
# 1
# Epoch 500: Current Learning Rate: [0.0003620037481497942, 0.0018100187407489718, 0.0001810018740748971]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  525  is done!
# 1
# Epoch 525: Current Learning Rate: [0.0003601980668004751, 0.0018009903340023758, 0.00018009903340023754]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  550  is done!
# 1
# Epoch 550: Current Learning Rate: [0.0003584013922229144, 0.0017920069611145728, 0.0001792006961114572]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  575  is done!
# 1
# Epoch 575: Current Learning Rate: [0.00035661367949116915, 0.001783068397455846, 0.00017830683974558458]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  600  is done!
# 1
# Epoch 600: Current Learning Rate: [0.00035483488390338755, 0.0017741744195169382, 0.00017741744195169377]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  625  is done!
# 1
# Epoch 625: Current Learning Rate: [0.0003530649609806916, 0.0017653248049034587, 0.0001765324804903458]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  650  is done!
# 1
# Epoch 650: Current Learning Rate: [0.0003513038664660649, 0.001756519332330325, 0.00017565193323303244]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  675  is done!
# 1
# Epoch 675: Current Learning Rate: [0.00034955155632324564, 0.0017477577816162287, 0.00017477577816162282]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  700  is done!
# 1
# Epoch 700: Current Learning Rate: [0.00034780798673562593, 0.00173903993367813, 0.00017390399336781297]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  725  is done!
# 1
# Epoch 725: Current Learning Rate: [0.0003460731141051556, 0.0017303655705257783, 0.0001730365570525778]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  750  is done!
# 1
# Epoch 750: Current Learning Rate: [0.00034434689505125256, 0.0017217344752562633, 0.00017217344752562628]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  775  is done!
# 1
# Epoch 775: Current Learning Rate: [0.00034262928640971794, 0.00171314643204859, 0.00017131464320485897]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  800  is done!
# 1
# Epoch 800: Current Learning Rate: [0.0003409202452316565, 0.001704601226158283, 0.00017046012261582826]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  825  is done!
# 1
# Epoch 825: Current Learning Rate: [0.00033921972878240317, 0.001696098643912016, 0.00016960986439120158]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  850  is done!
# 1
# Epoch 850: Current Learning Rate: [0.0003375276945404538, 0.0016876384727022686, 0.0001687638472702269]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  875  is done!
# 1
# Epoch 875: Current Learning Rate: [0.0003358441001964024, 0.0016792205009820117, 0.0001679220500982012]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  900  is done!
# 1
# Epoch 900: Current Learning Rate: [0.0003341689036518833, 0.0016708445182594155, 0.00016708445182594164]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  925  is done!
# 1
# Epoch 925: Current Learning Rate: [0.00033250206301851807, 0.0016625103150925892, 0.00016625103150925903]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  950  is done!
# 1
# Epoch 950: Current Learning Rate: [0.00033084353661686817, 0.0016542176830843397, 0.00016542176830843409]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  975  is done!
# 1
# Epoch 975: Current Learning Rate: [0.0003291932829753931, 0.001645966414876964, 0.00016459664148769655]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1000  is done!
# 1
# Epoch 1000: Current Learning Rate: [0.0003275512608294128, 0.0016377563041470632, 0.0001637756304147064]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1025  is done!
# 1
# Epoch 1025: Current Learning Rate: [0.0003259174291200768, 0.0016295871456003825, 0.0001629587145600384]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1050  is done!
# 1
# Epoch 1050: Current Learning Rate: [0.00032429174699333637, 0.0016214587349666803, 0.00016214587349666819]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1075  is done!
# 1
# Epoch 1075: Current Learning Rate: [0.00032267417379892394, 0.0016133708689946174, 0.00016133708689946197]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1100  is done!
# 1
# Epoch 1100: Current Learning Rate: [0.00032106466908933567, 0.0016053233454466763, 0.00016053233454466783]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1125  is done!
# 1
# Epoch 1125: Current Learning Rate: [0.0003194631926188212, 0.001597315963094104, 0.0001597315963094106]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1150  is done!
# 1
# Epoch 1150: Current Learning Rate: [0.0003178697043423763, 0.0015893485217118803, 0.00015893485217118814]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1175  is done!
# 1
# Epoch 1175: Current Learning Rate: [0.00031628416441474246, 0.001581420822073711, 0.00015814208220737123]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1200  is done!
# 1
# Epoch 1200: Current Learning Rate: [0.0003147065331894094, 0.001573532665947046, 0.0001573532665947047]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1225  is done!
# 1
# Epoch 1225: Current Learning Rate: [0.00031313677121762475, 0.0015656838560881236, 0.00015656838560881237]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1250  is done!
# 1
# Epoch 1250: Current Learning Rate: [0.00031157483924740736, 0.0015578741962370367, 0.00015578741962370368]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1275  is done!
# 1
# Epoch 1275: Current Learning Rate: [0.0003100206982225654, 0.0015501034911128266, 0.0001550103491112827]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1300  is done!
# 1
# Epoch 1300: Current Learning Rate: [0.0003084743092817201, 0.0015423715464085999, 0.00015423715464086006]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1325  is done!
# 1
# Epoch 1325: Current Learning Rate: [0.00030693563375733403, 0.0015346781687866696, 0.00015346781687866702]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1350  is done!
# 1
# Epoch 1350: Current Learning Rate: [0.00030540463317474414, 0.0015270231658737197, 0.00015270231658737207]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1375  is done!
# 1
# Epoch 1375: Current Learning Rate: [0.0003038812692511997, 0.0015194063462559975, 0.00015194063462559986]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)
# episode  1400  is done!
# 1
# Epoch 1400: Current Learning Rate: [0.00030236550389490505, 0.0015118275194745234, 0.00015118275194745252]
# /var/folders/tp/g5d5jn1j0x3d60w7kqpbj6wm0000gn/T/ipykernel_95544/28972780.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gae = torch.tensor(gae)

# %%
print(min(success_rates))
# Out:
# 980

# %%
# Out:
# 101 220

# %%
test_env = sim_constrained.Env(visualise=True, verbose=False, model=True, test=True, goal="min_time",graph = True)
_, state_data, action_mask = env.reset()

done = False

while not done:
    action = ppo_agent.select_action(state_data, memory, action_mask)
    #print(action)
    state_data, reward, done, action_mask, success_rate = test_env.step(action)
    #print(state, reward, done, action_mask, success_rate )
# Out:
# All products are produced at time:  1067
# From total  20  order,  0  was before their due dates. Success rate is:  0.0 %
# <div>                            <div id="c17ab258-396f-4a02-850a-4af9c15f8e54" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c17ab258-396f-4a02-850a-4af9c15f8e54")) {                    Plotly.newPlot(                        "c17ab258-396f-4a02-850a-4af9c15f8e54",                        [{"fill":"toself","fillcolor":"rgb(214, 39, 40)","hoverinfo":"name","legendgroup":"rgb(214, 39, 40)","mode":"none","name":"PRODUCT_4","showlegend":true,"x":[0,96,96,0,0,96,192,192,96,96,96,192,192,96,96,192,288,288,192,192,192,288,288,192,192,192,288,288,192,192,288,384,384,288,288,288,384,384,288,288,288,384,384,288,288,384,480,480,384,384,384,480,480,384,384,425,532,532,425,425,480,576,576,480,480,532,639,639,532,532,573,680,680,573,573,639,746,746,639,639,680,786,786,680,680,787,894,894,787],"y":[1.6,1.6,2.4,2.4,null,1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,1.6,1.6,2.4,2.4,null,-0.4,-0.4,0.4,0.4,null,0.6,0.6,1.4,1.4,null,1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,-0.4,-0.4,0.4,0.4,null,0.6,0.6,1.4,1.4,null,-0.4,-0.4,0.4,0.4,null,1.6,1.6,2.4,2.4,null,-0.4,-0.4,0.4,0.4,null,0.6,0.6,1.4,1.4,null,1.6,1.6,2.4,2.4,null,-0.4,-0.4,0.4,0.4,null,0.6,0.6,1.4,1.4,null,-0.4,-0.4,0.4,0.4],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(255, 127, 14)","hoverinfo":"name","legendgroup":"rgb(255, 127, 14)","mode":"none","name":"PRODUCT_2","showlegend":true,"x":[532,552,552,532,532,639,659,659,639,639,680,700,700,680,680,741,761,761,741,741,746,766,766,746,746,782,802,802,782,782,786,806,806,786,786,806,816,816,806,806,833,853,853,833,833,857,877,877,857,857,894,914,914,894,894,898,918,918,898,898,935,955,955,935,935,976,996,996,976,976,1047,1067,1067,1047],"y":[1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,1.6,1.6,2.4,2.4,null,1.6,1.6,2.4,2.4,null,-0.4,-0.4,0.4,0.4,null,1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,0.6,0.6,1.4,1.4,null,1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,-0.4,-0.4,0.4,0.4,null,0.6,0.6,1.4,1.4,null,-0.4,-0.4,0.4,0.4,null,-0.4,-0.4,0.4,0.4,null,-0.4,-0.4,0.4,0.4],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(31, 119, 180)","hoverinfo":"name","legendgroup":"rgb(31, 119, 180)","mode":"none","name":"PRODUCT_1","showlegend":true,"x":[404,425,425,404,404,480,501,501,480,480,552,573,573,552,552,596,616,616,596,596,659,680,680,659,659,720,741,741,720,720,761,782,782,761,761,766,787,787,766,766,802,823,823,802,802,823,833,833,823,823,836,857,857,836,836,853,874,874,853,853,877,898,898,877,877,918,939,939,918,918,939,949,949,939,939,949,959,959,949,949,955,976,976,955,955,996,1017,1017,996,996,1017,1027,1027,1017,1017,1027,1037,1037,1027,1027,1037,1047,1047,1037],"y":[1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,1.6,1.6,2.4,2.4,null,-0.4,-0.4,0.4,0.4,null,0.6,0.6,1.4,1.4,null,1.6,1.6,2.4,2.4,null,1.6,1.6,2.4,2.4,null,-0.4,-0.4,0.4,0.4,null,1.6,1.6,2.4,2.4,null,1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,0.6,0.6,1.4,1.4,null,0.6,0.6,1.4,1.4,null,0.6,0.6,1.4,1.4,null,-0.4,-0.4,0.4,0.4,null,-0.4,-0.4,0.4,0.4,null,-0.4,-0.4,0.4,0.4,null,-0.4,-0.4,0.4,0.4,null,-0.4,-0.4,0.4,0.4],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(44, 160, 44)","hoverinfo":"name","legendgroup":"rgb(44, 160, 44)","mode":"none","name":"PRODUCT_3","showlegend":true,"x":[384,404,404,384,384,501,521,521,501,501,576,596,596,576,576,700,720,720,700,700,816,836,836,816,816,914,935,935,914],"y":[1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,-0.4,-0.4,0.4,0.4,null,1.6,1.6,2.4,2.4,null,0.6,0.6,1.4,1.4,null,-0.4,-0.4,0.4,0.4],"type":"scatter"},{"legendgroup":"rgb(214, 39, 40)","marker":{"color":"rgb(214, 39, 40)","opacity":0,"size":1},"mode":"markers","name":"","showlegend":false,"text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...

# %%
#torch.save(ppo_agent, '/Users/hazarckr/Documents/Semester_3/idp/schedulingGNN/trainedModel2.pth')

# %% [markdown]
# Freezed Values:
#
# self.actor = nn.Sequential(
#             nn.Linear(n_states, 512),
#
#             nn.PReLU(),
#
#             nn.Linear(512, 256),
#             nn.ReLU(),
#
#             nn.Linear(256, 128),
#
#             nn.LeakyReLU(),
#             nn.Linear(128, 64),
#             nn.LeakyReLU(),
#
#             nn.Linear(64, n_actions),
#         )
#         self.critic = nn.Sequential(
#             nn.Linear(n_states, 128),
#             nn.LeakyReLU(),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, 1)
#
#
# ppo_agent = PPO(n_states, n_actions, lr_actor=0.00007, lr_critic=0.003, gamma=0.98, K_epochs=10, eps_clip=0.08, gae_lambda=0.97)
# memory = Memory()
#
# initial_temperature = 3  # Starting temperature
# final_temperature = 1    # Minimum temperature
# decay_rate = 0.001          # Rate of temperature decay
# current_temperature = initial_temperature
